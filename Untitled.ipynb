# %%
import pydub
AS = pydub.AudioSegment
from scipy.io.wavfile import read, write
import numpy as np
from IPython.display import Audio
import matplotlib.pyplot as plt
from scipy import signal

# %%
mp3 = AS.from_file('Obvious.mp3')
mp3.export('obv', format = 'wav')
# Out:
# <_io.BufferedRandom name='obv'>

# %%
Fs, data = read('obv')

# %%
data = data[:, 0]

# %%
data.shape
# Out:
# (14176373,)

# %%
plt.plot(data[4000000:6000000])
plt.show()

# %%
f, t, z = signal.stft(data[500000:700000], Fs, nperseg = 5)

plt.pcolormesh(t, f, np.abs(z))

# %%
f, t, z = signal.stft(data[500000:699999], Fs, nperseg = 100, return_onesided = True)

# %%
print([t.shape, f.shape, z.shape])
# Out:
# [(4001,), (51,), (51, 4001)]

# %%
plt.pcolormesh(t, f, np.abs(z))

# %%
Audio(data[500000:700000], rate = Fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
_, adata = signal.istft(z, Fs)

# %%
Audio(adata, rate = Fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
7000000-5000000
# Out:
# 2000000

# %%
a=[]
for i in range(z.shape[0]):
    for j in range(z.shape[1]):
        a.append(z[i][j].real)
        a.append(z[i][j].imag)

# %%
max(a)
# Out:
# 15184.195

# %%
min(a)
# Out:
# -14605.673

# %%
a = np.array(a)

# %%
np.std(a)
# Out:
# 446.5323

# %%
np.std?
